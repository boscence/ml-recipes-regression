# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # MLflow Regression Recipe Notebook
#
# This notebook runs the MLflow Regression Recipe on Databricks and inspects its results. For more information about the MLflow Regression Recipe, including usage examples, see the [Regression Recipe overview documentation](https://mlflow.org/docs/latest/recipes.html#regression-recipe) the [Regression Recipe API documentation](https://mlflow.org/docs/latest/python_api/mlflow.recipes.html#module-mlflow.recipes.regression.v1.recipe).

# %%
from mlflow.recipes import Recipe

r = Recipe(profile="local")
# Out:
# 2024/05/13 11:09:49 INFO mlflow.recipes.recipe: Creating MLflow Recipe 'ml-recipes-regression' with profile: 'local'

# %%
r.inspect()
# Out:
# <!DOCTYPE html>
# <html lang="en">
#   <body>
#     <style>
#       @keyframes spin {
#         to { transform: translate(calc(-50%), calc(50vh - 50%)) rotate(360deg); }
#       }
#       .mermaidTooltip {
#         display: none;
#       }
#       .wrapper {
#         display: flex;
#       }
#       .mermaid {
#         width: 60%;
#       }
#       .pane-loading {
#         font-size: 0;
#         color: transparent;
#       }
#       .pane-loading::after {
#         content: "";
#         position: absolute;
#         inset: 0 50%;
#         width: 32px;
#         height: 32px;
#         transform: translate(calc(-50%), calc(50vh - 50%));
#         border: 0.25rem solid #9370DB;
#         border-bottom: 0.25rem solid rgba(0,0,0,0);
#         border-radius: 50%;
#         animation: spin 1s linear infinite;
#       }
#       #editor {
#         font-size: 13px;
#         width: 40%;
#         position: relative;
#       }
#       font {
#         font-size: 24px;
#         padding: 24px;
#       }
#       .node:hover {
#         stroke: #2272B4 !important;
#         color: #0E538B !important;
#         background-color: #bbdaf4;
#       }
#     </style>
#
#     <div class="wrapper">
#       <div class="mermaid pane-loading">
#           flowchart TD
#
#           subgraph " "
#             recipe([recipe.yaml])
#
#             ingestUserCode([steps/ingest.py]) --> ingestMLPStep[["<font>ingest</font>"]]
#             ingestMLPStep --> dataParquet[(ingested_data)]
#
#             ingestScoringUserCode([steps/ingest.py]) --> ingestScoringMLPStep[["<font>ingest_scoring</font>"]]
#             ingestScoringMLPStep --> dataScoringParquet[(ingested_scoring_data)]
#
#             dataScoring[(ingested_scoring_data)] --> predictMLPStep[["<font>predict</font>"]]
#             predictMLPStep --> dataScored[(scored_data)]
#           end
#
#           data[(ingested_data)] --> splitStep[["<font>split</font>"]]
#           transformUserCode([steps/transform.py]) --> transformMLPStep
#           splitUserCode([steps/split.py]) --> splitStep
#           splitStep --> splitData0[(training_data)]
#           splitStep --> splitData1[(validation_data)]
#           splitStep --> splitData2[(test_data)]
#           splitData0 --> transformMLPStep[["<font>transform</font>"]]
#           splitData1 --> transformMLPStep[["<font>transform</font>"]]
#
#           transformMLPStep --> transformedParquet[(transformed_training_data, <br/> transformed_validation_data)]
#           transformMLPStep --> transformer
#           transformedParquet --> trainMLPStep[["<font>train</font>"]]
#
#           trainUserCode([steps/train.py]) --> trainMLPStep
#           customMetricsUserCode([steps/custom_metrics.py]) --> trainMLPStep
#           transformer --> trainMLPStep
#           trainMLPStep --> run
#           trainMLPStep --> model
#           trainMLPStep --> predictedTrainingData[(predicted_training_data)]
#
#           model --> evaluateMLPStep[["<font>evaluate</font>"]]
#           splitData1 --> evaluateMLPStep
#           splitData2 --> evaluateMLPStep
#           customMetricsUserCode --> evaluateMLPStep
#           evaluateMLPStep --> model_validation_status
#           run --> registerMLPStep[["<font>register</font>"]]
#           run --> evaluateMLPStep
#
#           model_validation_status --> registerMLPStep
#           registerMLPStep --> registered_model_version
#
#           click ingestMLPStep renderMoreInformation "{'help_string': 'The &bsol;&#39;ingest&bsol;&#39; step resolves the dataset specified by the &bsol;&#39;steps.ingest&bsol;&#39; section in recipe.yaml and converts it to parquet format, leveraging the custom dataset parsing code defined in `steps/ingest.py` (and referred to by the &bsol;&#39;loader_method&bsol;&#39; attribute of the &bsol;&#39;steps.ingest&bsol;&#39; section in recipe.yaml) if necessary. Subsequent steps convert this dataset into training, validation, & test sets and use them to develop a model. An example recipe.yaml &bsol;&#39;steps.ingest&bsol;&#39; configuration is shown below.\n\nsteps.ingest:\n  location: https://nyc-tlc.s3.amazonaws.com/trip+data/yellow_tripdata_2022-01.parquet\n  using: {{INGEST_DATA_FORMAT|default(&bsol;&#39;parquet&bsol;&#39;)}}\n  loader_method: load_file_as_dataframe\n', 'help_string_type': 'text'}"
#           click ingestUserCode renderMoreInformation "{'help_string': '&bsol;#quot;&bsol;#quot;&bsol;#quot;\nsteps/ingest.py defines customizable logic for parsing arbitrary dataset formats (i.e. formats that are not natively parsed by MLflow Recipes) via the `load_file_as_dataframe` function. Note that the Parquet, Delta, and Spark SQL dataset formats are natively parsed by MLflow Recipes, and you do not need to define custom logic for parsing them. An example `load_file_as_dataframe` implementation is displayed below (note that a different function name or module can be specified via the &bsol;&#39;loader_method&bsol;&#39; attribute of the &bsol;&#39;data&bsol;&#39; section in recipe.yaml).\n&bsol;#quot;&bsol;#quot;&bsol;#quot;\n\ndef load_file_as_dataframe(\n    file_path: str,\n    file_format: str,\n) -> pandas.DataFrame:\n    &bsol;#quot;&bsol;#quot;&bsol;#quot;\n    Load content from the specified dataset file as a Pandas DataFrame.\n\n    This method is used to load dataset types that are not natively  managed by MLflow Recipes (datasets that are not in Parquet, Delta Table, or Spark SQL Table format). This method is called once for each file in the dataset, and MLflow Recipes automatically combines the resulting DataFrames together.\n\n    :param file_path: The path to the dataset file.\n    :param file_format: The file format string, such as &bsol;#quot;csv&bsol;#quot;.\n    :return: A Pandas DataFrame representing the content of the specified file.\n    &bsol;#quot;&bsol;#quot;&bsol;#quot;\n', 'help_string_type': 'python'}"
#           click splitStep renderMoreInformation "{'help_string': 'The &bsol;&#39;split&bsol;&#39; step splits the ingested dataset produced by the &bsol;&#39;ingest&bsol;&#39; step into a training dataset for model training, a validation dataset for model performance evaluation & tuning, and a test dataset for model performance evaluation. The fraction of records allocated to each dataset is defined by the &bsol;&#39;split_ratios&bsol;&#39; attribute of the &bsol;&#39;split&bsol;&#39; step definition in recipe.yaml. The split step also preprocesses the datasets using logic defined in `steps/split.py` (and referred to by the &bsol;&#39;post_split_method&bsol;&#39; attribute of the &bsol;&#39;split&bsol;&#39; step definition in recipe.yaml). Subsequent steps use these datasets to develop a model and measure its performance. An example recipe.yaml &bsol;&#39;split&bsol;&#39; step definition is shown below.\n\nsteps:\n  split:\n    split_ratios: {{SPLIT_RATIOS|default([0.75, 0.125, 0.125])}}\n    post_split_filter_method: create_dataset_filter\n', 'help_string_type': 'text'}"
#           click transformMLPStep renderMoreInformation "{'help_string': 'The &bsol;&#39;transform&bsol;&#39; step uses the training dataset produced by &bsol;&#39;split&bsol;&#39; to fit a transformer with the transformation operations defined in `steps/transform.py` (and referred to by the &bsol;&#39;transformer_method&bsol;&#39; attribute of the &bsol;&#39;transform&bsol;&#39; step definition in recipe.yaml). The transformer is then applied to the training dataset and the validation dataset, producing transformed datasets that are used by subsequent steps for estimator training and model performance evaluation. An example recipe.yaml &bsol;&#39;transform&bsol;&#39; step definition is shown below.\n\nsteps:\n  transform:\n    using: custom\n    transformer_method: transformer_fn\n', 'help_string_type': 'text'}"
#           click transformUserCode renderMoreInformation "{'help_string': '&bsol;#quot;&bsol;#quot;&bsol;#quot;\nsteps/transform.py defines customizable logic for transforming input data during model inference. Transformations are specified via the via the `transformer_fn` function, an example of which is displayed below (note that a different function name or module can be specifi

# %%
r.run("ingest")
# Out:
# 2024/05/13 11:09:53 INFO mlflow.recipes.step: Running step ingest...
#
# Downloading artifacts:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading artifacts: 100%|██████████| 1/1 [00:00<00:00, 223.51it/s]
# Downloading artifacts: 100%|██████████| 1/1 [00:00<00:00, 210.76it/s]
# <!DOCTYPE html>
# <html>
#     <head>
#         <meta charset="UTF-8">
#         <title>Ingest@ml-recipes-regression</title>
#         <style>
#             h1.title {
#             color: #4287f5;
#             }
#             h2.step-title {
#                 color : #4287f5;
#             }
#             .tab {
#                 overflow: hidden;
#                 border: 1px solid #ccc;
#                 background-color: #f1f1f1;
#             }
#
#             .tab button {
#                 background-color: inherit;
#                 float: left;
#                 border: none;
#                 outline: none;
#                 cursor: pointer;
#                 padding: 14px 16px;
#                 transition: 0.3s;
#             }
#
#             .tab button:hover {
#                 background-color: #ddd;
#             }
#
#             .tab button.active {
#                 background-color: #ccc;
#             }
#
#             .tabcontent {
#                 display: block;
#                 padding: 6px 12px;
#                 border: 1px solid #ccc;
#                 border-top: none;
#             }
#
#             .content-hide {
#                 display: none;
#             }
#
#             .content-active {
#                 display: block;
#             }
#             h3.section-title {
#                 color: #57a8de;
#             }
#             .dataset-container {
#                 width: max;
#                 overflow-x: auto;
#                 white-space: nowrap;
#             }
#             .stacktrace-container {
#                 max-height: 300px;
#                 overflow: auto;
#                 display: flex;
#                 flex-direction: column-reverse;
#                 white-space: pre-wrap;
#             }
#         </style>
#     </head>
#    <body>
#         <div class="tab">
#             <div class="button-container-vdtezg">
#
#                     <button id=0 class="tablink-vdtezg">
#                         Data Profile
#                     </button>
#
#                     <button id=1 class="tablink-vdtezg">
#                         Data Schema
#                     </button>
#
#                     <button id=2 class="tablink-vdtezg">
#                         Data Preview
#                     </button>
#
#                     <button id=3 class="tablink-vdtezg">
#                         Run Summary
#                     </button>
#
#             </div>
#         </div>
#         <div class="tabcontent">
#
#                 <div class="content-vdtezg content-hide"><iframe srcdoc='
#         &lt;div style=&quot;background-color: white&quot;&gt;
#         &lt;script&gt;
# !function() {
#   let t = window.URL;
#   window.URL = function(n, e) {
#     if (typeof e === &quot;string&quot; &amp;&amp; e.startsWith(&quot;blob:&quot;)) {
#       return new URL(e);
#     } else {
#       return new t(n, e);
#     }
#   }
# }();
# &lt;/script&gt;
#         &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js&quot;&gt;&lt;/script&gt;
#         &lt;link rel=&quot;import&quot; href=&quot;https://raw.githubusercontent.com/PAIR-code/facets/1.0.0/facets-dist/facets-jupyter.html&quot; &gt;
#         &lt;facets-overview id=&quot;facets&quot; proto-input=&quot;...&quot; compare-mode=&quot;True&quot;&gt;&lt;/facets-overview&gt;
#         &lt;/div&gt;
#     ' width='100%' height='500' frameborder='0'></iframe></div>
#
#                 <div class="content-vdtezg content-hide"><div style="max-height: 500px; overflow: scroll;"><style type="text/css">
# #T_c3457 table {
#   border: 1px solid grey;
#   text-align: left;
#   padding: 5px;
# }
# #T_c3457  th {
#   border: 1px solid grey;
#   text-align: left;
#   padding: 5px;
# }
# #T_c3457  td {
#   border: 1px solid grey;
#   text-align: left;
#   padding: 5px;
# }
# </style>
# <table id="T_c3457" style="border-collapse:collapse">
#   <thead>
#     <tr>
#       <th id="T_c3457_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_c3457_level0_col1" class="col_heading level0 col1" >type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c3457_row0_col0" class="data row0 col0" >VendorID</td>
#       <td id="T_c3457_row0_col1" class="data row0 col1" >integer</td>
#     </tr>
#     <tr>
#       <td id="T_c3457_row1_col0" class="data row1 col0" >tpep_pickup_datetime</td>
#       <td id="T_c3457_row1_col1" class="data row1 col1" >string</td>
#     </tr>
#     <tr>
#       <td id="T_c3457_row2_col0" class="data row2 col0" >tpep_dropoff_datetime</td>
#       <td id="T_c3457_row2_col1" class="data row2 col1" >string</td>
#     </tr>
#     <tr>
#       <td id="T_c3457_row3_col0" class="data row3 col0" >passenger_count</td>
#       <td id="T_c3457_row3_col1" class="data row3 col1" >number</td>
#     </tr>
#     <tr>
#       <td id="T_c3457_row4_col0" class="data row4 col0" >trip_distance</td>
#       <td id="T_c3457_row4_col1" class="data row4 col1" >number</td>
#     </tr>
#     <tr>
#       <td id="T_c3457_row5_col0" class="data row5 col0" >RatecodeID</td>
#       <td id="T_c3457_row5_col1" class="data row5 col1" >number</td>
#     </tr>
#     <tr>
#       <td id="T_c3457_row6_col0" class="data row6 col0" >store_and_fwd_flag</td>
#       <td id="T_c3457_row6_col1" class="data row6 col1" >string</td>
#     </tr>
#     <tr>
#       <td id="T_c3457_row7_col0" class="data row7 col0" >PULocationID</td>
#       <td id="T_c3457_row7_col1" class="data row7 col1" >integer</td>
#     </tr>
#     <tr>
#       <td id="T_c3457_row8_col0" class="data row8 col0" >DOLocationID</td>
#       <td id="T_c3457_row8_col1" class="data row8 col1" >integer</td>
#     </tr>
#     <tr>
#       <td id="T_c3457_row9_col0" class="data row9 col0" >payment_type</td>
#       <td id="T_c3457_row9_col1" class="data row9 col1" >integer</td>
#     </tr>
#     <tr>
#       <td id="T_c3457_row10_col0" class="data row10 col0" >fare_amount</td>
#       <td id="T_c3457_row10_col1" class="data row10 col1" >number</td>
#     </tr>
#     <tr>
#       <td id="T_c3457_row11_col0" class="data row11 col0" >extra</td>
#       <td id="T_c3457_row11_col1" class="data row11 col1" >number</td>
#     </tr>
#     <tr>
#       <td id="T_c3457_row12_col0" class="data row12 col0" >mta_tax</td>
#       <td id="T_c3457_row12_col1" class="data row12 col1" >number</td>
#     </tr>
#     <tr>
#       <td id="T_c3457_row13_col0" class="data row13 col0" >tip_amount</td>
#       <td id="T_c3457_row13_col1" class="data row13 col1" >number</td>
#     </tr>
#     <tr>
#       <td id="T_c3457_row14_col0" class="data row14 col0" >tolls_amount</td>
#       <td id="T_c3457_row14_col1" class="data row14 col1" >number</td>
#     </tr>
#     <tr>
#       <td id="T_c3457_row15_col0" class="data row15 col0" >improvement_surcharge</td>
#       <td id="T_c3457_row15_col1" class="data row15 col1" >number</td>
#     </tr>
#     <tr>
#       <td id="T_c3457_row16_col0" class="data row16 col0" >total_amount</td>
#       <td id="T_c3457_row16_col1" class="data row16 col1" >number</td>
#     </tr>
#     <tr>
#       <td id="T_c3457_row17_col0" class="data row17 col0" >congestion_surcharge</td>
#       <td id="T_c3457_row17_col1" class="data row17 col1" >number</td>
#     </tr>
#     <tr>
#       <td id="T_c3457_row18_col0" class="data row18 col0" >Airport_fee</td>
#       <td id="T_c3457_row18_col1" class="data row18 col1" >number</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
#
#                 <div class="content-vdtezg content-hide"><div style="max-height: 500px; overflow: scroll;"><style type="text/css">
# #T_d457b table {
#   border: 1px solid grey;
#   text-align: left;
#   padding: 5px;
# }
# #T_d457b  th {
#   border: 1px solid grey;
#   text-align: left;
#   padding: 5px;
# }
# #T_d457b  td {
#   border: 1px solid grey;
#   text-align: left;
#   padding: 5px;
# }
# </style>
# <table id="T_d457b" style="border-collapse:collapse">
#   <thead>
#     <tr>
#       <th id="T_d457b_level0_col0" class="col_heading level0 col0" >VendorID</th>
#       <th id="T_d457b_level0_col1" class="col_heading level0 col1" >tpep_pickup_datetime</th>
#       <th id="T_d457b_level0_col2" class="col_heading level0 col2" >tpep_dropoff_datetime</th>
#       <th id="T_d457b_level0_col3" class="col_heading level0 co

# %%
r.run("split")
# Out:
# 2024/05/13 11:10:03 INFO mlflow.recipes.utils.execution: ingest: No changes. Skipping.
# Run MLflow Recipe step: split
# 2024/05/13 11:10:05 INFO mlflow.recipes.step: Running step split...
# /home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# <!DOCTYPE html>
# <html>
#     <head>
#         <meta charset="UTF-8">
#         <title>Split@ml-recipes-regression</title>
#         <style>
#             h1.title {
#             color: #4287f5;
#             }
#             h2.step-title {
#                 color : #4287f5;
#             }
#             .tab {
#                 overflow: hidden;
#                 border: 1px solid #ccc;
#                 background-color: #f1f1f1;
#             }
#
#             .tab button {
#                 background-color: inherit;
#                 float: left;
#                 border: none;
#                 outline: none;
#                 cursor: pointer;
#                 padding: 14px 16px;
#                 transition: 0.3s;
#             }
#
#             .tab button:hover {
#                 background-color: #ddd;
#             }
#
#             .tab button.active {
#                 background-color: #ccc;
#             }
#
#             .tabcontent {
#                 display: block;
#                 padding: 6px 12px;
#                 border: 1px solid #ccc;
#                 border-top: none;
#             }
#
#             .content-hide {
#                 display: none;
#             }
#
#             .content-active {
#                 display: block;
#             }
#             h3.section-title {
#                 color: #57a8de;
#             }
#             .dataset-container {
#                 width: max;
#                 overflow-x: auto;
#                 white-space: nowrap;
#             }
#             .stacktrace-container {
#                 max-height: 300px;
#                 overflow: auto;
#                 display: flex;
#                 flex-direction: column-reverse;
#                 white-space: pre-wrap;
#             }
#         </style>
#     </head>
#    <body>
#         <div class="tab">
#             <div class="button-container-lba3i8">
#
#                     <button id=0 class="tablink-lba3i8">
#                         Compare Splits
#                     </button>
#
#                     <button id=1 class="tablink-lba3i8">
#                         Run Summary
#                     </button>
#
#             </div>
#         </div>
#         <div class="tabcontent">
#
#                 <div class="content-lba3i8 content-hide"><iframe srcdoc='
#         &lt;div style=&quot;background-color: white&quot;&gt;
#         &lt;script&gt;
# !function() {
#   let t = window.URL;
#   window.URL = function(n, e) {
#     if (typeof e === &quot;string&quot; &amp;&amp; e.startsWith(&quot;blob:&quot;)) {
#       return new URL(e);
#     } else {
#       return new t(n, e);
#     }
#   }
# }();
# &lt;/script&gt;
#         &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js&quot;&gt;&lt;/script&gt;
#         &lt;link rel=&quot;import&quot; href=&quot;https://raw.githubusercontent.com/PAIR-code/facets/1.0.0/facets-dist/facets-jupyter.html&quot; &gt;
#         &lt;facets-overview id=&quot;facets&quot; proto-input=&quot;...&quot; compare-mode=&quot;True&quot;&gt;&lt;/facets-overview&gt;
#         &lt;/div&gt;
#     ' width='100%' height='500' frameborder='0'></iframe></div>
#
#                 <div class="content-lba3i8 content-hide">
#
#                 <p><strong>Number of train dataset rows:</strong> <code>121355</code></p>
#                 <p><strong>Number of validation dataset rows:</strong> <code>55597</code></p>
#                 <p><strong>Number of test dataset rows:</strong> <code>60583</code></p>
#                 <p><strong>Number of dropped rows:</strong> <code>0</code></p>
#                 <p><strong>Run duration (s)</strong>: 12.6</p>
#                 <p><strong>Last updated:</strong> 2024-05-13 11:10:18</p>
#                 </div>
#
#         </div>
#         <script>
#             function onclickTab(event) {
#                  const tablinks = document.getElementsByClassName("tablink-lba3i8");
#                 for (i = 0; i < tablinks.length; i++) {
#                     tablinks[i].className = tablinks[i].className.replace("active", "");
#                 }
#                 event.target.classList.add("active");
#
#                 const tabId = event.target.id;
#                 const tabContents = document.getElementsByClassName("content-lba3i8");
#                 for (i = 0; i < tabContents.length; i++) {
#                     tabContents[i].className = tabContents[i].className.replace("content-active", "content-hide");
#                 }
#                 tabContents[tabId].classList.add("content-active");
#             }
#             (function() {
#                 const buttonsContainer = document.getElementsByClassName("button-container-lba3i8")[0]
#                 buttonsContainer.addEventListener("click", onclickTab);
#
#                 const tablinks = document.getElementsByClassName("tablink-lba3i8");
#                 tablinks[0].classList.add("active");
#                 const tabContents = document.getElementsByClassName("content-lba3i8");
#                 tabContents[0].classList.add("content-active");
#             })()
#         </script>
#    </body>
# </html>

# %%
training_data = r.get_artifact("training_data")
training_data.describe()
# Out:
#             VendorID  passenger_count  trip_distance     RatecodeID  \
# count  121355.000000    121355.000000  121355.000000  121355.000000
# mean        1.762449         1.437279       4.046236       2.274847
# std         0.425584         0.928201       6.614756      10.581854
# min         1.000000         0.000000       0.000000       1.000000
# 25%         2.000000         1.000000       1.070000       1.000000
# 50%         2.000000         1.000000       1.870000       1.000000
# 75%         2.000000         2.000000       4.000000       1.000000
# max         2.000000         8.000000     971.800000      99.000000
#
#         PULocationID   DOLocationID   payment_type    fare_amount  \
# count  121355.000000  121355.000000  121355.000000  121355.000000
# mean      162.383866     162.125615       1.284331      20.625233
# std        62.627028      70.345092       0.584139      21.888461
# min         1.000000       1.000000       1.000000    -351.600000
# 25%       132.000000     113.000000       1.000000       8.600000
# 50%       161.000000     162.000000       1.000000      12.800000
# 75%       230.000000     233.000000       1.000000      23.300000
# max       265.000000     265.000000       4.000000     620.400000
#
#                extra        mta_tax     tip_amount   tolls_amount  \
# count  121355.000000  121355.000000  121355.000000  121355.000000
# mean        1.508040       0.477257       3.525596       0.739963
# std         1.876998       0.135322       4.486918       2.516734
# min        -7.500000      -0.500000     -22.240000     -55.340000
# 25%         0.000000       0.500000       0.000000       0.000000
# 50%         1.000000       0.500000       2.600000       0.000000
# 75%         2.500000       0.500000       4.300000       0.000000
# max        11.750000       0.500000     130.000000     101.690000
#
#        improvement_surcharge   total_amount  congestion_surcharge  \
# count          121355.000000  121355.000000         121355.000000
# mean                0.968514      29.668219              2.162025
# std                 0.248213      27.061553              0.940425
# min                -1.000000    -374.040000             -2.500000
# 25%                 1.000000      15.300000              2.500000
# 50%                 1.000000      20.470000              2.500000
# 75%                 1.000000      31.875000              2.500000
# max                 1.000000     630.090000              2.500000
#
#          Airport_fee
# count  121355.000000
# mean        0.207670
# std         0.577688
# min        -1.750000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.750000

# %%
r.run("transform")
# Out:
# 2024/05/13 11:12:08 INFO mlflow.recipes.utils.execution: ingest, split: No changes. Skipping.
# Run MLflow Recipe step: transform
# 2024/05/13 11:12:12 INFO mlflow.recipes.step: Running step transform...
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/mlflow/recipes/step.py", line 132, in run
#     self.step_card = self._run(output_directory=output_directory)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/mlflow/recipes/steps/transform.py", line 135, in _run
#     transformer.fit(train_df.drop(columns=[self.target_col]), train_df[self.target_col])
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/base.py", line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/pipeline.py", line 471, in fit
#     Xt = self._fit(X, y, routed_params)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/pipeline.py", line 408, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/joblib/memory.py", line 312, in __call__
#     return self.func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/pipeline.py", line 1303, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 295, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/base.py", line 1101, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 295, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/preprocessing/_function_transformer.py", line 292, in transform
#     out = adapter.create_container(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 134, in create_container
#     return self.rename_columns(X_output, columns)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 144, in rename_columns
#     X.columns = columns
#     ^^^^^^^^^
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/pandas/core/generic.py", line 6313, in __setattr__
#     return object.__setattr__(self, name, value)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "properties.pyx", line 69, in pandas._libs.properties.AxisProperty.__set__
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/pandas/core/generic.py", line 814, in _set_axis
#     self._mgr.set_axis(axis, labels)
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/pandas/core/internals/managers.py", line 238, in set_axis
#     self._validate_set_axis(axis, new_labels)
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/pandas/core/internals/base.py", line 98, in _validate_set_axis
#     raise ValueError(
# ValueError: Length mismatch: Expected axis has 19 elements, new values have 18 elements
# make: *** [Makefile:31: steps/transform/outputs/transformer.pkl] Error 1
# <!DOCTYPE html>
# <html>
#     <head>
#         <meta charset="UTF-8">
#         <title>Transform@ml-recipes-regression</title>
#         <style>
#             h1.title {
#             color: #4287f5;
#             }
#             h2.step-title {
#                 color : #4287f5;
#             }
#             .tab {
#                 overflow: hidden;
#                 border: 1px solid #ccc;
#                 background-color: #f1f1f1;
#             }
#
#             .tab button {
#                 background-color: inherit;
#                 float: left;
#                 border: none;
#                 outline: none;
#                 cursor: pointer;
#                 padding: 14px 16px;
#                 transition: 0.3s;
#             }
#
#             .tab button:hover {
#                 background-color: #ddd;
#             }
#
#             .tab button.active {
#                 background-color: #ccc;
#             }
#
#             .tabcontent {
#                 display: block;
#                 padding: 6px 12px;
#                 border: 1px solid #ccc;
#                 border-top: none;
#             }
#
#             .content-hide {
#                 display: none;
#             }
#
#             .content-active {
#                 display: block;
#             }
#             h3.section-title {
#                 color: #57a8de;
#             }
#             .dataset-container {
#                 width: max;
#                 overflow-x: auto;
#                 white-space: nowrap;
#             }
#             .stacktrace-container {
#                 max-height: 300px;
#                 overflow: auto;
#                 display: flex;
#                 flex-direction: column-reverse;
#                 white-space: pre-wrap;
#             }
#         </style>
#     </head>
#    <body>
#         <div class="tab">
#             <div class="button-container-ggbwzu">
#
#                     <button id=0 class="tablink-ggbwzu">
#                         Step Status
#                     </button>
#
#                     <button id=1 class="tablink-ggbwzu">
#                         Stacktrace
#                     </button>
#
#             </div>
#         </div>
#         <div class="tabcontent">
#
#                 <div class="content-ggbwzu content-hide"><p><strong>Step status: <span style="color:red">Failed</span></strong></p></div>
#
#                 <div class="content-ggbwzu content-hide"><div class='stacktrace-container'><p style='margin-top:0px'><code>Traceback (most recent call last):
#   File &#34;/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/mlflow/recipes/step.py&#34;, line 132, in run
#     self.step_card = self._run(output_directory=output_directory)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File &#34;/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/mlflow/recipes/steps/transform.py&#34;, line 135, in _run
#     transformer.fit(train_df.drop(columns=[self.target_col]), train_df[self.target_col])
#   File &#34;/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/base.py&#34;, line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File &#34;/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/pipeline.py&#34;, line 471, in fit
#     Xt = self._fit(X, y, routed_params)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File &#34;/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/pipeline.py&#34;, line 408, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File &#34;/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/joblib/memory.py&#34;, line 312, in __call__
#     return self.func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File &#34;/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/pipeline.py&#34;, line 1303, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **params.get(&#34;fit_transform&#34;, {}))
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File &#34;/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/utils/_set_output.py&#34;, line 295, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File &#34;/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/base.py&#34;, line 1101, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File &#34;/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/utils/_set_output.py&#34;, line 295, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File &#34;/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/preprocessing/_function_transformer.py&#34;, line 292, in transform
#     out = adapter.create_container(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File &#34;/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/utils/_set_output.py&#34;, line 134, in create_container
#     return self.rename_columns(X_output, columns)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File &#34;/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/utils/_set_output.py&#34;, line 144, in rename_columns
#     X.columns = columns
#     ^^^^^^^^^
#   File &#34;/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/pandas/core/generic.py&#34;, line 6313, in __setattr__
#     return object.__setattr__(self, name, value)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File &#34;properties.pyx&#34;, line 69, in pandas._libs.properties.AxisProperty.__set__
#   File &#34;/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/pandas/core/generic.py&#34;, line 814, in _set_axis
#     self._mgr.set_axis(axis, labels)
#   File &#34;/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/pandas/core/internals/managers.py&#34;, line 238, in set_axis
#     self._validate_set_axis(axis, new_labels)
#   File &#34;/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/pandas/core/internals/base.py&#34;, line 98, in _validate_set_axis
#     raise ValueError(
# ValueError: Length mismatch: Expected axis has 19 elements, new values have 18 elements
# </code></p></div></div>
#
#         </div>
#         <script>
#             function onclickTab(event) {
#                  const tablinks = document.getElementsByClassName("tablink-ggbwzu");
#                 for (i = 0; i < tablinks.length; i++) {
#                     tablinks[i].className = tablinks[i].className.replace("active", "");
#                 }
#                 event.target.classList.add("active");
#
#                 const tabId = event.target.id;
#                 const tabContents = document.getElementsByClassName("content-ggbwzu");
#                 for (i = 0; i < tabContents.length; i++) {
#                     tabContents[i].className = tabContents[i].className.replace("content-active", "content-hide");
#                 }
#                 tabContents[tabId].classList.add("content-active");
#             }
#             (function() {
#                 const buttonsContainer = document.getElementsByClassName("button-container-ggbwzu")[0]
#                 buttonsContainer.addEventListener("click", onclickTab);
#
#                 const tablinks = document.getElementsByClassName("tablink-ggbwzu");
#                 tablinks[0].classList.add("active");
#                 const tabContents = document.getElementsByClassName("content-ggbwzu");
#                 tabContents[0].classList.add("content-active");
#             })()
#         </script>
#    </body>
# </html>
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# /home/user/ml-recipes-regression/notebooks/jupyter.ipynb Cell 9 line 1
# ----> <a href='vscode-notebook-cell://monospace-ml-recipes-regression-1715579515315.cluster-3g4scxt2njdd6uovkqyfcabgo6.cloudworkstations.dev/home/user/ml-recipes-regression/notebooks/jupyter.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> r.run("transform")
#
# File ~/ml-recipes-regression/venv/lib/python3.11/site-packages/mlflow/recipes/regression/v1/recipe.py:284, in RegressionRecipe.run(self, step)
#     211 def run(self, step: Optional[str] = None) -> None:
#     212     """
#     213     Runs the full recipe or a particular recipe step, producing outputs and displaying a
#     214     summary of results upon completion. Step outputs are cached from previous executions, and
#    (...)
#     282         regression_recipe.run()
#     283     """
# --> 284     return super().run(step=step)
#
# File ~/ml-recipes-regression/venv/lib/python3.11/site-packages/mlflow/recipes/recipe.py:106, in BaseRecipe.run(self, step)
#     100 last_step_error_mesg = (
#     101     f"The following error occurred while running step '{last_executed_step}':\n"
#     102     f"{last_executed_step_state.stack_trace}\n"
#     103     f"Last step status: '{last_executed_step_state.status}'\n"
#     104 )
#     105 if step is not None:
# --> 106     raise MlflowException(
#     107         f"Failed to run step '{step}' of recipe '{self.name}':\n{last_step_error_mesg}",
#     108         error_code=BAD_REQUEST,
#     109     )
#     110 else:
#     111     raise MlflowException(
#     112         f"Failed to run recipe '{self.name}':\n{last_step_error_mesg}",
#     113         error_code=BAD_REQUEST,
#     114     )
#
# MlflowException: Failed to run step 'transform' of recipe 'ml-recipes-regression':
# The following error occurred while running step 'Step:transform':
# Traceback (most recent call last):
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/mlflow/recipes/step.py", line 132, in run
#     self.step_card = self._run(output_directory=output_directory)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/mlflow/recipes/steps/transform.py", line 135, in _run
#     transformer.fit(train_df.drop(columns=[self.target_col]), train_df[self.target_col])
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/base.py", line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/pipeline.py", line 471, in fit
#     Xt = self._fit(X, y, routed_params)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/pipeline.py", line 408, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/joblib/memory.py", line 312, in __call__
#     return self.func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/pipeline.py", line 1303, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 295, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/base.py", line 1101, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 295, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/preprocessing/_function_transformer.py", line 292, in transform
#     out = adapter.create_container(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 134, in create_container
#     return self.rename_columns(X_output, columns)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 144, in rename_columns
#     X.columns = columns
#     ^^^^^^^^^
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/pandas/core/generic.py", line 6313, in __setattr__
#     return object.__setattr__(self, name, value)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "properties.pyx", line 69, in pandas._libs.properties.AxisProperty.__set__
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/pandas/core/generic.py", line 814, in _set_axis
#     self._mgr.set_axis(axis, labels)
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/pandas/core/internals/managers.py", line 238, in set_axis
#     self._validate_set_axis(axis, new_labels)
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/pandas/core/internals/base.py", line 98, in _validate_set_axis
#     raise ValueError(
# ValueError: Length mismatch: Expected axis has 19 elements, new values have 18 elements
#
# Last step status: 'StepStatus.FAILED'

# %%
r.run("train")
# Out:
# 2024/05/13 10:40:20 INFO mlflow.recipes.utils.execution: ingest, split: No changes. Skipping.
# Run MLflow Recipe step: transform
# 2024/05/13 10:40:22 INFO mlflow.recipes.step: Running step transform...
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/mlflow/recipes/step.py", line 132, in run
#     self.step_card = self._run(output_directory=output_directory)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/mlflow/recipes/steps/transform.py", line 135, in _run
#     transformer.fit(train_df.drop(columns=[self.target_col]), train_df[self.target_col])
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/base.py", line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/pipeline.py", line 471, in fit
#     Xt = self._fit(X, y, routed_params)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/pipeline.py", line 408, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/joblib/memory.py", line 312, in __call__
#     return self.func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/pipeline.py", line 1303, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 295, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/base.py", line 1101, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 295, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/preprocessing/_function_transformer.py", line 292, in transform
#     out = adapter.create_container(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 134, in create_container
#     return self.rename_columns(X_output, columns)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 144, in rename_columns
#     X.columns = columns
#     ^^^^^^^^^
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/pandas/core/generic.py", line 6313, in __setattr__
#     return object.__setattr__(self, name, value)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "properties.pyx", line 69, in pandas._libs.properties.AxisProperty.__set__
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/pandas/core/generic.py", line 814, in _set_axis
#     self._mgr.set_axis(axis, labels)
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/pandas/core/internals/managers.py", line 238, in set_axis
#     self._validate_set_axis(axis, new_labels)
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/pandas/core/internals/base.py", line 98, in _validate_set_axis
#     raise ValueError(
# ValueError: Length mismatch: Expected axis has 19 elements, new values have 18 elements
# make: *** [Makefile:31: steps/transform/outputs/transformed_training_data.parquet] Error 1
# <!DOCTYPE html>
# <html>
#     <head>
#         <meta charset="UTF-8">
#         <title>Transform@ml-recipes-regression</title>
#         <style>
#             h1.title {
#             color: #4287f5;
#             }
#             h2.step-title {
#                 color : #4287f5;
#             }
#             .tab {
#                 overflow: hidden;
#                 border: 1px solid #ccc;
#                 background-color: #f1f1f1;
#             }
#
#             .tab button {
#                 background-color: inherit;
#                 float: left;
#                 border: none;
#                 outline: none;
#                 cursor: pointer;
#                 padding: 14px 16px;
#                 transition: 0.3s;
#             }
#
#             .tab button:hover {
#                 background-color: #ddd;
#             }
#
#             .tab button.active {
#                 background-color: #ccc;
#             }
#
#             .tabcontent {
#                 display: block;
#                 padding: 6px 12px;
#                 border: 1px solid #ccc;
#                 border-top: none;
#             }
#
#             .content-hide {
#                 display: none;
#             }
#
#             .content-active {
#                 display: block;
#             }
#             h3.section-title {
#                 color: #57a8de;
#             }
#             .dataset-container {
#                 width: max;
#                 overflow-x: auto;
#                 white-space: nowrap;
#             }
#             .stacktrace-container {
#                 max-height: 300px;
#                 overflow: auto;
#                 display: flex;
#                 flex-direction: column-reverse;
#                 white-space: pre-wrap;
#             }
#         </style>
#     </head>
#    <body>
#         <div class="tab">
#             <div class="button-container-ujr6as">
#
#                     <button id=0 class="tablink-ujr6as">
#                         Step Status
#                     </button>
#
#                     <button id=1 class="tablink-ujr6as">
#                         Stacktrace
#                     </button>
#
#             </div>
#         </div>
#         <div class="tabcontent">
#
#                 <div class="content-ujr6as content-hide"><p><strong>Step status: <span style="color:red">Failed</span></strong></p></div>
#
#                 <div class="content-ujr6as content-hide"><div class='stacktrace-container'><p style='margin-top:0px'><code>Traceback (most recent call last):
#   File &#34;/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/mlflow/recipes/step.py&#34;, line 132, in run
#     self.step_card = self._run(output_directory=output_directory)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File &#34;/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/mlflow/recipes/steps/transform.py&#34;, line 135, in _run
#     transformer.fit(train_df.drop(columns=[self.target_col]), train_df[self.target_col])
#   File &#34;/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/base.py&#34;, line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File &#34;/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/pipeline.py&#34;, line 471, in fit
#     Xt = self._fit(X, y, routed_params)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File &#34;/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/pipeline.py&#34;, line 408, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File &#34;/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/joblib/memory.py&#34;, line 312, in __call__
#     return self.func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File &#34;/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/pipeline.py&#34;, line 1303, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **params.get(&#34;fit_transform&#34;, {}))
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File &#34;/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/utils/_set_output.py&#34;, line 295, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File &#34;/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/base.py&#34;, line 1101, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File &#34;/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/utils/_set_output.py&#34;, line 295, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File &#34;/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/preprocessing/_function_transformer.py&#34;, line 292, in transform
#     out = adapter.create_container(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File &#34;/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/utils/_set_output.py&#34;, line 134, in create_container
#     return self.rename_columns(X_output, columns)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File &#34;/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/utils/_set_output.py&#34;, line 144, in rename_columns
#     X.columns = columns
#     ^^^^^^^^^
#   File &#34;/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/pandas/core/generic.py&#34;, line 6313, in __setattr__
#     return object.__setattr__(self, name, value)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File &#34;properties.pyx&#34;, line 69, in pandas._libs.properties.AxisProperty.__set__
#   File &#34;/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/pandas/core/generic.py&#34;, line 814, in _set_axis
#     self._mgr.set_axis(axis, labels)
#   File &#34;/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/pandas/core/internals/managers.py&#34;, line 238, in set_axis
#     self._validate_set_axis(axis, new_labels)
#   File &#34;/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/pandas/core/internals/base.py&#34;, line 98, in _validate_set_axis
#     raise ValueError(
# ValueError: Length mismatch: Expected axis has 19 elements, new values have 18 elements
# </code></p></div></div>
#
#         </div>
#         <script>
#             function onclickTab(event) {
#                  const tablinks = document.getElementsByClassName("tablink-ujr6as");
#                 for (i = 0; i < tablinks.length; i++) {
#                     tablinks[i].className = tablinks[i].className.replace("active", "");
#                 }
#                 event.target.classList.add("active");
#
#                 const tabId = event.target.id;
#                 const tabContents = document.getElementsByClassName("content-ujr6as");
#                 for (i = 0; i < tabContents.length; i++) {
#                     tabContents[i].className = tabContents[i].className.replace("content-active", "content-hide");
#                 }
#                 tabContents[tabId].classList.add("content-active");
#             }
#             (function() {
#                 const buttonsContainer = document.getElementsByClassName("button-container-ujr6as")[0]
#                 buttonsContainer.addEventListener("click", onclickTab);
#
#                 const tablinks = document.getElementsByClassName("tablink-ujr6as");
#                 tablinks[0].classList.add("active");
#                 const tabContents = document.getElementsByClassName("content-ujr6as");
#                 tabContents[0].classList.add("content-active");
#             })()
#         </script>
#    </body>
# </html>
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# /home/user/ml-recipes-regression/notebooks/jupyter.ipynb Cell 9 line 1
# ----> <a href='vscode-notebook-cell://monospace-ml-recipes-regression-1715579515315.cluster-3g4scxt2njdd6uovkqyfcabgo6.cloudworkstations.dev/home/user/ml-recipes-regression/notebooks/jupyter.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> r.run("train")
#
# File ~/ml-recipes-regression/venv/lib/python3.11/site-packages/mlflow/recipes/regression/v1/recipe.py:284, in RegressionRecipe.run(self, step)
#     211 def run(self, step: Optional[str] = None) -> None:
#     212     """
#     213     Runs the full recipe or a particular recipe step, producing outputs and displaying a
#     214     summary of results upon completion. Step outputs are cached from previous executions, and
#    (...)
#     282         regression_recipe.run()
#     283     """
# --> 284     return super().run(step=step)
#
# File ~/ml-recipes-regression/venv/lib/python3.11/site-packages/mlflow/recipes/recipe.py:106, in BaseRecipe.run(self, step)
#     100 last_step_error_mesg = (
#     101     f"The following error occurred while running step '{last_executed_step}':\n"
#     102     f"{last_executed_step_state.stack_trace}\n"
#     103     f"Last step status: '{last_executed_step_state.status}'\n"
#     104 )
#     105 if step is not None:
# --> 106     raise MlflowException(
#     107         f"Failed to run step '{step}' of recipe '{self.name}':\n{last_step_error_mesg}",
#     108         error_code=BAD_REQUEST,
#     109     )
#     110 else:
#     111     raise MlflowException(
#     112         f"Failed to run recipe '{self.name}':\n{last_step_error_mesg}",
#     113         error_code=BAD_REQUEST,
#     114     )
#
# MlflowException: Failed to run step 'train' of recipe 'ml-recipes-regression':
# The following error occurred while running step 'Step:transform':
# Traceback (most recent call last):
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/mlflow/recipes/step.py", line 132, in run
#     self.step_card = self._run(output_directory=output_directory)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/mlflow/recipes/steps/transform.py", line 135, in _run
#     transformer.fit(train_df.drop(columns=[self.target_col]), train_df[self.target_col])
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/base.py", line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/pipeline.py", line 471, in fit
#     Xt = self._fit(X, y, routed_params)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/pipeline.py", line 408, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/joblib/memory.py", line 312, in __call__
#     return self.func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/pipeline.py", line 1303, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 295, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/base.py", line 1101, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 295, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/preprocessing/_function_transformer.py", line 292, in transform
#     out = adapter.create_container(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 134, in create_container
#     return self.rename_columns(X_output, columns)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 144, in rename_columns
#     X.columns = columns
#     ^^^^^^^^^
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/pandas/core/generic.py", line 6313, in __setattr__
#     return object.__setattr__(self, name, value)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "properties.pyx", line 69, in pandas._libs.properties.AxisProperty.__set__
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/pandas/core/generic.py", line 814, in _set_axis
#     self._mgr.set_axis(axis, labels)
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/pandas/core/internals/managers.py", line 238, in set_axis
#     self._validate_set_axis(axis, new_labels)
#   File "/home/user/ml-recipes-regression/venv/lib/python3.11/site-packages/pandas/core/internals/base.py", line 98, in _validate_set_axis
#     raise ValueError(
# ValueError: Length mismatch: Expected axis has 19 elements, new values have 18 elements
#
# Last step status: 'StepStatus.FAILED'

# %%
trained_model = r.get_artifact("model")
print(trained_model)

# %%
r.run("evaluate")

# %%
r.run("register")
